# %% [markdown]
# ### INF 510 Fall 2019 Final Project Submission

# %% [markdown]
# 1.	**The names of team member(s)**:
#
#     Jinhong_Lei

# %% [markdown]
# 2.  **How to run your code (what command-line switches they are, what happens when you invoke the code, etc.)**
#
#     This project requires the following packages:
#     - requests,beautifulsoup,re,argparse,sqlite3,matplotlib.pyplot,matplotlib,numpy,csv
#
#     To run this project, make sure the above packages are installed, and then simply clone the repo at https://github.com/Jinhong1003/inf510_project and execute this notebook
#
#     There are 3 parts of my code, including “-source=remote, local, test”.
#
#     When you invoke the -source=remote, the code will use beautiful soup firstly scrape the webpages and get 500 great songs’ names and who is the singer, then it will scrape the webpage which contains the top100 most common words in English, next the code will query the API based on the data about 500 songs we already had in order to get the lyrics of each song.save them in a csv file,After these, the code will clean the lyrics and save all the data in the database which is called “allwords”, finally the code will test the database to do some visualizations, like make a bar chart and pie chart.
#
#     When you invoke the -source=test, this part is only designed for the grade in order to save the time to create database, this part almost the same as -source=remote, just reduce the number of songs from 500 to 200.
#
#     When you invoke the -source=local,read the csv file clean the csv file and make a database. the code will select the data that I need and do some visualizations, including bar chart, pie chart, scatter plot in order to make a result, and it can also print the result. After you invoke this part, the code will require you to input bar chart/pie chart/scatter plot/conclusion/all/quit, so that the code will give you what you want.

# %% [markdown]
# 3.	**Any major “gotchas” to the code (i.e. things that don’t work, go slowly, could be improved, etc.)**
#
#     Although I have scraped 500 songs from the web, some of the songs that cannot find the lyrics through the API, this might because the database in the API is not that big so the API cannot find the lyrics of these songs, the format of the names could also be a reason, when I cleaned the data, I might forget to correct the format and some kinds of punctuation.

# %% [markdown]
# 4.  **Anything else you feel is relevant to the grading of your project your project.**
#
#     my project, I think the database I made is big enough to make a conclusion that is 500 songs’ lyrics, including more than 30000 words, and I use SQL to make data base so it is really convenient to select what I want in the data. I have done visualizations and make a reasonable conclusion in my project.
#
#     In addition, in milestone 2,I put the cleaning procedure in the -source=remote part, and I just submit the database that already cleaned as the data that I should submit for the final, according to the lecture, this might be more reasonable and professor approved it.so that, in the -source=local part as known as milestone 3, I can just do analyze work.
#
#     however,i changed it accroding to the advise from TA, i saved the raw data first, cleaned it and then put it to the database, finally i i do some visualizations on the data from database.

# %% [markdown]
# 5. **What did you set out to study?  (i.e. what was the point of your project?  This should be close to your Milestone 1 assignment, but if you switched gears or changed things, note it here.)**
#
#     the point of my project is to find out whether we should write lyrics with most common words as many as possible or not, based on comparing the two data sets, one contains 500 popular songs’ lyrics, and another contains most common words in English, so the most important part of my project is selecting data and making a database there are a lot of words in both data sets that may show vulgarized lyrics are more acceptable by the listeners, otherwise listeners like distinctive lyrics better. According to this project research outcome, I can give a good suggestion to lyricist.

# %% [markdown]
# 6. **What did you Discover/what were your conclusions (i.e. what were your findings?  Were your original assumptions confirmed, etc.?)**
#
#     According to the visualization we have done, there are 64% of common words are popular lyrics, and the more popular lyric it is the more common words it belongs to. In conclusion, song writers should right the song use the word as common as possible so that the song will be easier to become popular and great, so that my original assumptions confirmed.

# %% [markdown]
# 7. **What difficulties did you have in completing the project?**
#
#     Firstly, it is very difficult to clean the data that I scraped from the website, there might have some punctuations and unknow marks in the data that the API cannot recognize, and same thing happened in the lyric data, I tried my best to clean them, fortunately, I got a quiet well result. Secondly, I spent a lot of time in considering how to combine the data I get and show my data accurately so that the users can understand the result quickly.

# %% [markdown]
# 8. **What skills did you wish you had while you were doing the project?**
#
#
#     I wish I had a large amount of knowledge in statistics, so that the conclusion I made could be more compellent, and I also hope that I can be more familiar about some other libraries in order to do some interesting things that I have never considered.

# %% [markdown]
# 9. **What would you do “next” to expand or augment the project?**
#
#     Next, I want to find more lyrics to expand my database so that the conclusion will be more reasonable, and so far, I have only considered the lyrics in English, next, I would like to think about some lyrics in foreign languages, like Chinese , Japanese or others, and try my best to take the result as a whole, finally I can make a very significant conclusion.

# %%
import requests
from bs4 import BeautifulSoup
import re
import argparse
import sqlite3
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import csv

import Lei_Jinhong_finalproject

# %% [markdown]
# In this case, I want to find out whether we should write lyrics with most common words as many as possible or not, based on comparing the two data sets, one contains 500 popular songs’ lyrics, and another contains most common words in English. If there are a lot of words in both data sets that may show vulgarized lyrics are more acceptable by the listeners, otherwise listeners like distinctive lyrics better. According to this project research outcome, I can give a good suggestion to lyricist.

# %%
##cleaning the data before upload to the database


a=Lei_Jinhong_finalproject.cleandata()  
top100list=Lei_Jinhong_finalproject.gettop100list(a)
lyric_common_words=Lei_Jinhong_finalproject.getlyric_common_words(a)

Lei_Jinhong_finalproject.top100list=top100list
Lei_Jinhong_finalproject.lyric_common_words=lyric_common_words

# %%
##create database,uplouad data and do visualization
try:
        Lei_Jinhong_finalproject.creatdatabase()
        Lei_Jinhong_finalproject.insert_top100wordlist()
        Lei_Jinhong_finalproject.insert_lyric_common_wordlist()
        Lei_Jinhong_finalproject.showoutput()

except:
        Lei_Jinhong_finalproject.showoutput()
# Out:
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# New entry added
# ...

# %% [markdown]
# all the codes above are the project that i want to complete, you need to input the kind of output you want,including bar chart/pie chart/scatter plot/conclusion/all/quit,so that you can receive whatever you want.
# I recommend that you can input "all" to get all the result.
# Next i will separete the visualization missions and explain.
# !!!!!Don't forget to input quit to quit the codes above.

# %%
#######take a look about the tables in database###



conn = sqlite3.connect('Allwords.db')
cur = conn.cursor()
a=cur.execute("""
                SELECT * From lyric_common_wordlist

                """).fetchall()

b=cur.execute("""
                 SELECT * From top100wordlist

                """).fetchall()
print(a)
print("____________________________________")
print(b)
# Out:
# [(0, 'i', 4380), (1, 'the', 3611), (2, 'you', 3523), (3, 'is', 2243), (4, 'and', 2158), (5, 'to', 2136), (6, 'a', 2079), (7, 'not', 1689), (8, 'it', 1412), (9, 'my', 1370), (10, 'me', 1335), (11, 'in', 1187), (12, 'do', 1018), (13, 'that', 939), (14, 'on', 895), (15, 'of', 851), (16, 'all', 823), (17, 'will', 809), (18, 'am', 791), (19, 'can', 789), (20, 'be', 758), (21, 'your', 752), (22, 'love', 735), (23, 'for', 675), (24, 'are', 664), (25, 'we', 602), (26, 'but', 596), (27, 'just', 585), (28, 'she', 542), (29, 'got', 536), (30, 'have', 534), (31, 'so', 505), (32, 'know', 497), (33, 'with', 495), (34, 'get', 479), (35, 'when', 438), (36, 'he', 437), (37, 'what', 428), (38, 'they', 422), (39, 'like', 418), (40, 'up', 381), (41, 'now', 378), (42, 'no', 375), (43, 'oh', 359), (44, 'baby', 338), (45, 'yeah', 331), (46, 'go', 331), (47, 'was', 331), (48, 'this', 330), (49, 'o', 330), (50, 'if', 324), (51, 'one', 309), (52, 'come', 303), (53, 'let', 303), (54, 'down', 301), (55, 'there'
# ...

# %%
Lei_Jinhong_finalproject.makebarchart()

# %% [markdown]
# From the bar chart, the first one,we can see that the top 100 most popular lyric wors and the times that they appeared in 500songs,and the second one we can see  the top20 exact words and the times as well,the most popular words is "i" which appears nearly 5000 times which means each song has 10 "i" average.

# %%
Lei_Jinhong_finalproject.makepiechart()

# %% [markdown]
# This is a very meaningful pie chart,there are 64% common Engilsh words belongs to popular lyric words, more than half!

# %%
Lei_Jinhong_finalproject.makeScatterplot()

# %% [markdown]
# according to the scatter plot,the words in both English common words list and popular lyric words list have the same trend in how popular they are.
# So we can make a conclusion!!!

# %%
Lei_Jinhong_finalproject.result()
# Out:
# ____________________________________result______________________________________
# There are three kinds of pictures in my project,including bar,pie and scatters.
# According to the visualization we have done,there are 64% of common words are
# popular lyrics,and the more popular lyric it is the more common words it belongs to.
# In conclusion,song writers should right the song use the word as common as
# possible so that the song will be easier to become popular and great!
# ________________________________________________________________________________
